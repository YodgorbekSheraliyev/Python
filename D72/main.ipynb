# %%
import pandas as pd

# %%
df = pd.read_csv('salaries_by_college_major.csv')

# %%
df.head()
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting             46,000.0000               77,100.0000
# 1  Aerospace Engineering             57,700.0000              101,000.0000
# 2            Agriculture             42,600.0000               71,900.0000
# 3           Anthropology             36,800.0000               61,500.0000
# 4           Architecture             41,600.0000               76,800.0000
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                        42,200.0000                       152,000.0000
# 1                        64,300.0000                       161,000.0000
# 2                        36,300.0000                       150,000.0000
# 3                        33,800.0000                       138,000.0000
# 4                        50,600.0000                       136,000.0000
#
#       Group
# 0  Business
# 1      STEM
# 2  Business
# 3      HASS
# 4  Business

# %%
#To get number of rows and columns in data we use .shape property
df.shape
# Out:
# (51, 6)

# %%
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
df.isna()
# Out:
#     Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0                 False                   False                     False
# 1                 False                   False                     False
# 2                 False                   False                     False
# 3                 False                   False                     False
# 4                 False                   False                     False
# 5                 False                   False                     False
# 6                 False                   False                     False
# 7                 False                   False                     False
# 8                 False                   False                     False
# 9                 False                   False                     False
# 10                False                   False                     False
# 11                False                   False                     False
# ...

# %%
clear_df = df.dropna()

# %%
clear_df
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 0                             Accounting             46,000.0000
# 1                  Aerospace Engineering             57,700.0000
# 2                            Agriculture             42,600.0000
# 3                           Anthropology             36,800.0000
# 4                           Architecture             41,600.0000
# 5                            Art History             35,800.0000
# 6                                Biology             38,800.0000
# 7                    Business Management             43,000.0000
# 8                   Chemical Engineering             63,200.0000
# 9                              Chemistry             42,600.0000
# 10                     Civil Engineering             53,900.0000
# 11                        Communications             38,100.0000
# 12                  Computer Engineering             61,400.0000
# ...

# %%
clear_df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
df['Starting Median Salary']
# Out:
# 0    46,000.0000
# 1    57,700.0000
# 2    42,600.0000
# 3    36,800.0000
# 4    41,600.0000
# 5    35,800.0000
# 6    38,800.0000
# 7    43,000.0000
# 8    63,200.0000
# 9    42,600.0000
# 10   53,900.0000
# 11   38,100.0000
# 12   61,400.0000
# 13   55,900.0000
# 14   53,700.0000
# 15   35,000.0000
# 16   35,900.0000
# 17   50,100.0000
# 18   34,900.0000
# 19   60,900.0000
# 20   38,000.0000
# 21   37,900.0000
# 22   47,900.0000
# 23   39,100.0000
# 24   41,200.0000
# 25   43,500.0000
# 26   35,700.0000
# 27   38,800.0000
# 28   39,200.0000
# 29   37,800.0000
# 30   57,700.0000
# 31   49,100.0000
# 32   36,100.0000
# 33   40,900.0000
# 34   35,600.0000
# 35   49,200.0000
# 36   40,800.0000
# 37   45,400.0000
# 38   57,900.0000
# 39   35,900.0000
# 40   54,200.0000
# 41   39,900.0000
# 42   39,900.0000
# 43   74,300.0000
# 44   50,300.0000
# 45   40,800.0000
# 46   35,900.0000
# 47   34,100.0000
# 48   36,500.0000
# 49   34,000.0000
# 50           NaN
# ...

# %%
df['Starting Median Salary'].max()
# Out:
# np.float64(74300.0)

# %%
df['Starting Median Salary'].idxmax()
# Out:
# 43

# %%
df['Starting Median Salary'].loc[43]
# Out:
# np.float64(74300.0)

# %%
df['Undergraduate Major'][43]
# Out:
# 'Physician Assistant'

# %%
df.loc[43]
# Out:
# Undergraduate Major                  Physician Assistant
# Starting Median Salary                       74,300.0000
# Mid-Career Median Salary                     91,700.0000
# Mid-Career 10th Percentile Salary            66,400.0000
# Mid-Career 90th Percentile Salary           124,000.0000
# Group                                               STEM
# Name: 43, dtype: object

# %%
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
df['Mid-Career Median Salary'].max()
# Out:
# np.float64(107000.0)

# %%
df['Mid-Career Median Salary'].idxmax()
# Out:
# 8

# %%
df['Undergraduate Major'][8]
# Out:
# 'Chemical Engineering'

# %%
clear_df.loc[clear_df['Mid-Career Median Salary'].idxmin()]
# Out:
# Undergraduate Major                    Education
# Starting Median Salary               34,900.0000
# Mid-Career Median Salary             52,000.0000
# Mid-Career 10th Percentile Salary    29,300.0000
# Mid-Career 90th Percentile Salary   102,000.0000
# Group                                       HASS
# Name: 18, dtype: object

# %%
#spread_col = clear_df['Mid-Career 90th Percentile Salary'] - clear_df['Mid-Career 10th Percentile Salary']
spread_col = clear_df['Mid-Career 90th Percentile Salary'].subtract(clear_df['Mid-Career 10th Percentile Salary'])

# %%
spread_col
# Out:
# 0    109,800.0000
# 1     96,700.0000
# 2    113,700.0000
# 3    104,200.0000
# 4     85,400.0000
# 5     96,200.0000
# 6     98,100.0000
# 7    108,200.0000
# 8    122,100.0000
# 9    102,700.0000
# 10    84,600.0000
# 11   105,500.0000
# 12    95,900.0000
# 13    98,000.0000
# 14   114,700.0000
# 15    74,800.0000
# 16   116,300.0000
# 17   159,400.0000
# 18    72,700.0000
# 19    98,700.0000
# 20    99,600.0000
# 21   102,100.0000
# 22   147,800.0000
# 23    70,000.0000
# 24    92,000.0000
# 25   111,000.0000
# 26    76,000.0000
# 27    66,400.0000
# 28   112,000.0000
# 29    88,500.0000
# 30   115,900.0000
# 31    84,500.0000
# 32    71,300.0000
# 33   118,800.0000
# 34   106,600.0000
# 35   100,700.0000
# 36   132,900.0000
# 37   137,800.0000
# 38    99,300.0000
# 39   107,300.0000
# 40    50,700.0000
# 41    65,300.0000
# 42   132,500.0000
# 43    57,600.0000
# 44   122,000.0000
# 45   126,800.0000
# 46    95,400.0000
# 47    66,700.0000
# 48    87,300.0000
# 49    65,400.0000
# ...

# %%
clear_df.insert(1, "Spread", spread_col)

# %%
clear_df.head()
# Out:
#      Undergraduate Major       Spread  Starting Median Salary  \
# 0             Accounting 109,800.0000             46,000.0000
# 1  Aerospace Engineering  96,700.0000             57,700.0000
# 2            Agriculture 113,700.0000             42,600.0000
# 3           Anthropology 104,200.0000             36,800.0000
# 4           Architecture  85,400.0000             41,600.0000
#
#    Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 0               77,100.0000                        42,200.0000
# 1              101,000.0000                        64,300.0000
# 2               71,900.0000                        36,300.0000
# 3               61,500.0000                        33,800.0000
# 4               76,800.0000                        50,600.0000
#
#    Mid-Career 90th Percentile Salary     Group
# 0                       152,000.0000  Business
# 1                       161,000.0000      STEM
# 2                       150,000.0000  Business
# ...

# %%
low_risk = clear_df.sort_values("Spread", ascending=True)
low_risk
# Out:
#                      Undergraduate Major       Spread  Starting Median Salary  \
# 40                               Nursing  50,700.0000             54,200.0000
# 43                   Physician Assistant  57,600.0000             74,300.0000
# 41                             Nutrition  65,300.0000             39,900.0000
# 49                               Spanish  65,400.0000             34,000.0000
# 27            Health Care Administration  66,400.0000             38,800.0000
# 47                              Religion  66,700.0000             34,100.0000
# 23                              Forestry  70,000.0000             39,100.0000
# 32                       Interior Design  71,300.0000             36,100.0000
# 18                             Education  72,700.0000             34,900.0000
# 15                      Criminal Justice  74,800.0000             35,000.0000
# 26                        Graphic Design  76,000.0000             35,700.0000
# ...

# %%
low_risk[['Undergraduate Major', 'Spread', 'Group']]
# Out:
#                      Undergraduate Major       Spread     Group
# 40                               Nursing  50,700.0000  Business
# 43                   Physician Assistant  57,600.0000      STEM
# 41                             Nutrition  65,300.0000      HASS
# 49                               Spanish  65,400.0000      HASS
# 27            Health Care Administration  66,400.0000  Business
# 47                              Religion  66,700.0000      HASS
# 23                              Forestry  70,000.0000  Business
# 32                       Interior Design  71,300.0000      HASS
# 18                             Education  72,700.0000      HASS
# 15                      Criminal Justice  74,800.0000      HASS
# 26                        Graphic Design  76,000.0000      HASS
# 31           Information Technology (IT)  84,500.0000      STEM
# 10                     Civil Engineering  84,600.0000      STEM
# 4                           Architecture  85,400.0000  Business
# ...

# %%
highest_potential = clear_df.sort_values("Mid-Career 10th Percentile Salary", ascending=False)
highest_potential[['Undergraduate Major','Mid-Career 90th Percentile Salary']].head()
# Out:
#        Undergraduate Major  Mid-Career 90th Percentile Salary
# 8     Chemical Engineering                       194,000.0000
# 19  Electrical Engineering                       168,000.0000
# 43     Physician Assistant                       124,000.0000
# 12    Computer Engineering                       162,000.0000
# 1    Aerospace Engineering                       161,000.0000

# %%
highest_spread = clear_df.sort_values("Spread", ascending=False)
highest_potential['Spread'].head()
# Out:
# 8    122,100.0000
# 19    98,700.0000
# 43    57,600.0000
# 12    95,900.0000
# 1     96,700.0000
# Name: Spread, dtype: float64

# %%
grouped_df = clear_df.select_dtypes(include='number').groupby(clear_df['Group']).mean()
grouped_df
# Out:
#                Spread  Starting Median Salary  Mid-Career Median Salary  \
# Group
# Business 103,958.3333             44,633.3333               75,083.3333
# HASS      95,218.1818             37,186.3636               62,968.1818
# STEM     101,600.0000             53,862.5000               90,812.5000
#
#           Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary
# Group
# Business                        43,566.6667                       147,525.0000
# HASS                            34,145.4545                       129,363.6364
# STEM                            56,025.0000                       157,625.0000

# %%
pd.options.display.float_format = '{:,.4f}'.format

# %%
grouped_df
# Out:
#                Spread  Starting Median Salary  Mid-Career Median Salary  \
# Group
# Business 103,958.3333             44,633.3333               75,083.3333
# HASS      95,218.1818             37,186.3636               62,968.1818
# STEM     101,600.0000             53,862.5000               90,812.5000
#
#           Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary
# Group
# Business                        43,566.6667                       147,525.0000
# HASS                            34,145.4545                       129,363.6364
# STEM                            56,025.0000                       157,625.0000
