# %% [markdown]
# # Introduction
#
# In this notebook, we will do a comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# # About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# # Import Statements

# %%
import pandas as pd

# %% [markdown]
# # Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
df_apps = pd.read_csv('apps.csv')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **Challenge**: How many rows and columns does `df_apps` have? What are the column names? Look at a random sample of 5 different rows with [.sample()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html).

# %%
df_apps.shape
# Out:
# (10841, 12)

# %%
random_df = df_apps.sample(5)
random_df
# Out:
#                                   App         Category  Rating  Reviews  \
# 778         Wallpapers Volvo FH Truck  PERSONALIZATION    4.20        4
# 5445             White Noise for Baby        PARENTING    4.90      717
# 3711  The Vietnam Story - Fun Stories           COMICS    4.50      438
# 2221             Currency Exchange DZ          FINANCE     NaN        4
# 6676   Lynda - Online Training Videos        EDUCATION    4.20     8599
#
#       Size_MBs   Installs  Type Price Content_Rating           Genres  \
# 778      14.00        100  Free     0           Teen  Personalization
# 5445      6.60    100,000  Free     0       Everyone        Parenting
# 3711      3.40     10,000  Free     0       Everyone           Comics
# 2221      2.50      1,000  Free     0       Everyone          Finance
# 6676     17.00  1,000,000  Free     0       Everyone        Education
#
#            Last_Updated   Android_Ver
# 778       July 31, 2016  2.3.3 and up
# ...

# %%
df_apps.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Android_Ver'],
#       dtype='object')

# %% [markdown]
# ### Drop Unused Columns
#
# **Challenge**: Remove the columns called `Last_Updated` and `Android_Version` from the DataFrame. We will not use these columns.

# %%
df_apps.drop(columns=['Last_Updated', 'Android_Ver'], inplace=True)

# %% [markdown]
# ### Find and Remove NaN values in Ratings
#
# **Challenge**: How may rows have a NaN value (not-a-number) in the Ratings column? Create DataFrame called `df_apps_clean` that does not include these rows.

# %%
df_apps_clean = df_apps.dropna()
df_apps_clean
# Out:
#                                                    App Category  Rating  \
# 21                                 KBA-EZ Health Guide  MEDICAL    5.00
# 28                                            Ra Ga Ba     GAME    5.00
# 47                                             Mu.F.O.     GAME    5.00
# 82                                    Brick Breaker BR     GAME    5.00
# 99     Anatomy & Physiology Vocabulary Exam Review App  MEDICAL    5.00
# ...                                                ...      ...     ...
# 10836                                   Subway Surfers     GAME    4.50
# 10837                                   Subway Surfers     GAME    4.50
# 10838                                   Subway Surfers     GAME    4.50
# 10839                                   Subway Surfers     GAME    4.50
# 10840                                   Subway Surfers     GAME    4.50
#
#         Reviews  Size_MBs       Installs  Type  Price Content_Rating   Genres
# ...

# %%
df_apps_clean.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres'],
#       dtype='object')

# %% [markdown]
# ### Find and Remove Duplicates
#
# **Challenge**: Are there any duplicates in data? Check for duplicates using the [.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) function. How many entries can you find for the "Instagram" app? Use [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) to remove any duplicates from `df_apps_clean`.

# %%
df_apps_clean.duplicated()
df_apps_clean.drop_duplicates(inplace=True)
# Out:
# C:\Users\shera\AppData\Local\Temp\ipykernel_13236\3082299252.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_apps_clean.drop_duplicates(inplace=True)

# %%
df_apps_clean.shape
# Out:
# (8891, 10)

# %% [markdown]
# # Find Highest Rated Apps
#
# **Challenge**: Identify which apps are the highest rated. What problem might you encounter if you rely exclusively on ratings alone to determine the quality of an app?

# %%
# df_apps_clean[df_apps_clean['Rating'] == df_apps_clean['Rating'].max()]
df_apps_clean.sort_values(by=['Rating', 'Reviews'], ascending=False).head()
# Out:
#                                                     App   Category  Rating  \
# 2095                                         Ríos de Fe  LIFESTYLE    5.00
# 2438  FD Calculator (EMI, SIP, RD & Loan Eligilibility)    FINANCE    5.00
# 3115                                         Oración CX  LIFESTYLE    5.00
# 2107                     Barisal University App-BU Face     FAMILY    5.00
# 2069                                         Master E.K     FAMILY    5.00
#
#       Reviews  Size_MBs Installs  Type Price Content_Rating     Genres
# 2095      141     15.00    1,000  Free     0       Everyone  Lifestyle
# 2438      104      2.30    1,000  Free     0       Everyone    Finance
# 3115      103      3.80    5,000  Free     0       Everyone  Lifestyle
# 2107      100     10.00    1,000  Free     0       Everyone  Education
# 2069       90     19.00    1,000  Free     0       Everyone  Education

# %% [markdown]
# # Find 5 Largest Apps in terms of Size (MBs)
#
# **Challenge**: What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be limit in place or can developers make apps as large as they please?

# %%
df_apps_clean.sort_values(by='Size_MBs', ascending=False).head()
# Out:
#                                   App   Category  Rating  Reviews  Size_MBs  \
# 9945                  Ultimate Tennis     SPORTS    4.30   183004    100.00
# 9944     Gangster Town: Vice District     FAMILY    4.30    65146    100.00
# 9943            Miami crime simulator       GAME    4.00   254518    100.00
# 9942   Talking Babsy Baby: Baby Games  LIFESTYLE    4.00   140995    100.00
# 10687          Hungry Shark Evolution       GAME    4.50  6074334    100.00
#
#           Installs  Type Price Content_Rating                  Genres
# 9945    10,000,000  Free     0       Everyone                  Sports
# 9944    10,000,000  Free     0     Mature 17+              Simulation
# 9943    10,000,000  Free     0     Mature 17+                  Action
# 9942    10,000,000  Free     0       Everyone  Lifestyle;Pretend Play
# 10687  100,000,000  Free     0           Teen                  Arcade

# %% [markdown]
# # Find the 5 App with Most Reviews
#
# **Challenge**: Which apps have the highest number of reviews? Are there any paid apps among the top 50?

# %%
df_apps_clean.sort_values(by=['Reviews'], ascending=False).head(50)
# Out:
#                                                      App       Category  \
# 10805                                           Facebook         SOCIAL
# 10811                                           Facebook         SOCIAL
# 10785                                 WhatsApp Messenger  COMMUNICATION
# 10797                                 WhatsApp Messenger  COMMUNICATION
# 10808                                          Instagram         SOCIAL
# 10806                                          Instagram         SOCIAL
# 10810                                          Instagram         SOCIAL
# 10790           Messenger – Text and Video Chat for Free  COMMUNICATION
# 10784           Messenger – Text and Video Chat for Free  COMMUNICATION
# 10652                                     Clash of Clans           GAME
# 10650                                     Clash of Clans           GAME
# 10653                                     Clash of Clans         FAMILY
# ...

# %% [markdown]
# # Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
ratings = df_apps_clean.Content_Rating.value_counts()
ratings.index
# Out:
# Index(['Everyone', 'Teen', 'Mature 17+', 'Everyone 10+', 'Adults only 18+',
#        'Unrated'],
#       dtype='object', name='Content_Rating')

# %%
import plotly.express as px

# %%
fig = px.pie(labels=ratings.index, values=ratings.values, names=ratings.index)
fig.update_traces(textposition='outside', textinfo ='label+percent')

# %%
fig = px.pie(labels=ratings.index, values=ratings.values, names=ratings.index, hole=0.5)
fig.update_traces(textposition='inside', textinfo ='percent')

# %% [markdown]
# # Numeric Type Conversion: Examine the Number of Installs
#
# **Challenge**: How many apps had over 1 billion (that's right - BILLION) installations? How many apps just had a single install?
#
# Check the datatype of the Installs column.
#
# Count the number of apps at each level of installations.
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have make sure you remove non-numeric characters first.

# %%
df_apps_clean.describe()
# Out:
#         Rating       Reviews  Size_MBs
# count 8,891.00      8,891.00  8,891.00
# mean      4.19    472,806.76     20.71
# std       0.52  2,905,214.05     22.18
# min       1.00          1.00      0.01
# 25%       4.00        164.00      5.10
# 50%       4.30      4,706.00     12.00
# 75%       4.50     71,128.50     29.00
# max       5.00 78,158,306.00    100.00

# %%
df_apps_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8891 entries, 21 to 10840
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8891 non-null   object
#  1   Category        8891 non-null   object
#  2   Rating          8891 non-null   float64
#  3   Reviews         8891 non-null   int64
#  4   Size_MBs        8891 non-null   float64
#  5   Installs        8891 non-null   object
#  6   Type            8891 non-null   object
#  7   Price           8891 non-null   object
#  8   Content_Rating  8891 non-null   object
#  9   Genres          8891 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 764.1+ KB

# %%
df_apps_clean.Installs.describe()
# Out:
# count          8891
# unique           19
# top       1,000,000
# freq           1486
# Name: Installs, dtype: object

# %%
df_apps_clean.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres'],
#       dtype='object')

# %%
df_apps_clean[['App', 'Installs']].groupby("Installs").count()
# Out:
#                 App
# Installs
# 1                 3
# 1,000           699
# 1,000,000      1486
# 1,000,000,000    49
# 10               69
# 10,000          989
# 10,000,000     1130
# 100             303
# 100,000        1110
# 100,000,000     369
# 5                 9
# 5,000           426
# 5,000,000       683
# 50               56
# 50,000          462
# 50,000,000      272
# 500             199
# 500,000         516
# 500,000,000      61

# %%
df_apps_clean.Installs = df_apps_clean.Installs.astype(str).str.replace(",", '')
df_apps_clean.Installs = pd.to_numeric(df_apps_clean.Installs)
# Out:
# C:\Users\shera\AppData\Local\Temp\ipykernel_13236\1725396360.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\shera\AppData\Local\Temp\ipykernel_13236\1725396360.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_apps_clean[['App', 'Installs']].groupby("Installs").count()
# Out:
#              App
# Installs
# 1              3
# 5              9
# 10            69
# 50            56
# 100          303
# 500          199
# 1000         699
# 5000         426
# 10000        989
# 50000        462
# 100000      1110
# 500000       516
# 1000000     1486
# 5000000      683
# 10000000    1130
# 50000000     272
# 100000000    369
# 500000000     61
# 1000000000    49

# %% [markdown]
# # Find the Most Expensive Apps, Filter out the Junk, and Calculate a (ballpark) Sales Revenue Estimate
#
# Let's examine the Price column more closely.
#
# **Challenge**: Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
#
# Remove all apps that cost more than $250 from the `df_apps_clean` DataFrame.
#
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %%
df_apps_clean.Price = df_apps_clean.Price.astype(str).str.replace("$", "")
df_apps_clean.Price = pd.to_numeric(df_apps_clean.Price)
df_apps_clean.sort_values(by='Price', ascending=False).head(20)
# Out:
# C:\Users\shera\AppData\Local\Temp\ipykernel_13236\1206383958.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\shera\AppData\Local\Temp\ipykernel_13236\1206383958.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                  App   Category  Rating  Reviews  Size_MBs  \
# 3946        I'm Rich - Trump Edition  LIFESTYLE    3.60      275      7.30
# 2775                   I Am Rich Pro     FAMILY    4.40      201      2.70
# ...

# %% [markdown]
# ### The most expensive apps sub $250

# %%
df_apps_clean = df_apps_clean[df_apps_clean.Price < 250]
df_apps_clean.sort_values("Price", ascending=False).head(20)
# Out:
#                                                     App     Category  Rating  \
# 2281                          Vargo Anesthesia Mega App      MEDICAL    4.60
# 1407                                       LTC AS Legal      MEDICAL    4.00
# 2629                                   I am Rich Person    LIFESTYLE    4.20
# 2481                            A Manual of Acupuncture      MEDICAL    3.50
# 2463                                 PTA Content Master      MEDICAL    4.20
# 504                           AP Art History Flashcards       FAMILY    5.00
# 2207                                           EMT PASS      MEDICAL    3.40
# 4264                            Golfshot Plus: Golf GPS       SPORTS    4.10
# 4774   Human Anatomy Atlas 2018: Complete 3D Human Body      MEDICAL    4.50
# 4772   Human Anatomy Atlas 2018: Complete 3D Human Body      MEDICAL    4.50
# 3241  Muscle Premium - Human Anatomy, Kinesiology, B...      MEDICAL    4.20
# ...

# %% [markdown]
# ### Highest Grossing Paid Apps (ballpark estimate)

# %%
df_apps_clean['Revenue Estimate'] = df_apps_clean.Price.mul(df_apps_clean.Installs)
df_apps_clean.sort_values('Revenue Estimate', ascending=False).head(20)
# df_apps_clean.sort_values('Revenue Estimate', ascending=False).groupby("App").head()
# print(df_apps_clean)
# Out:
# C:\Users\shera\AppData\Local\Temp\ipykernel_13236\4120922314.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                    App         Category  \
# 9220                                         Minecraft           FAMILY
# 9224                                         Minecraft           FAMILY
# 8825                                     Hitman Sniper             GAME
# 7151                     Grand Theft Auto: San Andreas             GAME
# 7977                           Sleep as Android Unlock        LIFESTYLE
# 7477                               Facetune - For Free      PHOTOGRAPHY
# 6594                               DraStic DS Emulator             GAME
# ...

# %% [markdown]
# # Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %%
top_category = df_apps_clean['Category'].value_counts()[:10]
top_category.values
# top_category.index
# Out:
# array([1714, 1074,  733,  334,  311,  310,  307,  304,  302,  301])

# %%
bar = px.bar(x=top_category.index, y=top_category.values, labels={"X": "Value", "Y": "Category"})
bar.show()

# %%
bar = px.bar(y=top_category.index, x=top_category.values, labels=top_category.index, orientation='h', title="Category Popularity")
bar.update_layout(xaxis_title='Number of downloads', yaxis_title='Categories')
bar.show()

# %%
category_installs = df_apps_clean.groupby("Category").aggregate({"Installs": "sum", "App": "count"})
category_installs.sort_values(by='Installs', ascending=False, inplace=True)
category_installs.head(10)

scatter = px.scatter(x=category_installs.App, y=category_installs.Installs, size=category_installs.App, hover_data=[category_installs.App])
scatter.show()

# %%
cat_number = df_apps_clean.groupby("Category").agg({"App": "count"})
cat_merged_df = pd.merge(cat_number, category_installs, on='Category', how='inner')

# %%
print(f'The dimensions of the DataFrame are: {cat_merged_df.shape}')
cat_merged_df.sort_values('Installs', ascending=False)
# Out:
# The dimensions of the DataFrame are: (33, 3)
#                      App_x     Installs  App_y
# Category
# GAME                  1074  31543862717   1074
# COMMUNICATION          307  24152241530    307
# SOCIAL                 244  12513841475    244
# PRODUCTIVITY           334  12463070180    334
# TOOLS                  733  11440724500    733
# FAMILY                1714  10041105490   1714
# PHOTOGRAPHY            304   9721243130    304
# TRAVEL_AND_LOCAL       205   6361859300    205
# VIDEO_PLAYERS          160   6221897200    160
# NEWS_AND_MAGAZINES     214   5393110650    214
# SHOPPING               201   2563331540    201
# ENTERTAINMENT          111   2455660000    111
# PERSONALIZATION        310   2074352930    310
# BOOKS_AND_REFERENCE    177   1916291655    177
# SPORTS                 286   1528531465    286
# HEALTH_AND_FITNESS     262   1361006220    262
# BUSINESS               270    863518120    270
# FINANCE                311    770249400    311
# ...

# %% [markdown]
# ### Vertical Bar Chart - Highest Competition (Number of Apps)

# %%
scatter = px.scatter(cat_merged_df, # data
                    x='App_x', # column name
                    y='Installs',
                    title='Category Concentration',
                    size='App_x',
                    hover_name=cat_merged_df.index,
                    color='Installs')
 
scatter.update_layout(xaxis_title="Number of Apps (Lower=More Concentrated)",
                      yaxis_title="Installs",
                      yaxis=dict(type='log'))

# %%
df_apps_clean.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres', 'Revenue Estimate'],
#       dtype='object')

# %% [markdown]
# ### Horizontal Bar Chart - Most Popular Categories (Highest Downloads)

# %%
df_apps_clean.Genres.unique()
# Out:
# array(['Medical', 'Arcade', 'Sports', 'Business', 'Books & Reference',
#        'Social', 'Tools', 'Education', 'Communication', 'Entertainment',
#        'Productivity', 'Action', 'Simulation', 'Casual', 'Lifestyle',
#        'Racing', 'Dating', 'Events', 'Maps & Navigation', 'Shopping',
#        'Personalization', 'Parenting', 'Photography', 'Puzzle',
#        'Health & Fitness', 'Education;Education', 'Food & Drink',
#        'News & Magazines', 'Finance', 'Role Playing', 'Trivia',
#        'Travel & Local', 'Adventure', 'Auto & Vehicles', 'Art & Design',
#        'Educational', 'Board;Brain Games', 'Beauty',
#        'Video Players & Editors', 'Board;Pretend Play', 'Casino',
#        'Comics', 'Board', 'Action;Action & Adventure', 'Word', 'Weather',
#        'Strategy', 'Card', 'Simulation;Education',
#        'Educational;Creativity', 'House & Home', 'Casual;Brain Games',
#        'Books & Reference;Education', 'Education;Pretend Play',
# ...

# %%
stack = df_apps_clean.Genres.str.split(";", expand=True).stack()
num_genres = stack.value_counts()
num_genres
# Out:
# Tools                      733
# Education                  626
# Entertainment              534
# Action                     364
# Productivity               334
# Finance                    311
# Personalization            310
# Communication              308
# Photography                304
# Sports                     303
# Medical                    302
# Lifestyle                  302
# Business                   270
# Health & Fitness           264
# Casual                     255
# Social                     244
# Arcade                     220
# News & Magazines           214
# Simulation                 210
# Travel & Local             205
# Shopping                   201
# Books & Reference          179
# Video Players & Editors    163
# Dating                     159
# Puzzle                     143
# Action & Adventure         125
# Maps & Navigation          124
# Role Playing               116
# Racing                     114
# Food & Drink               106
# ...

# %% [markdown]
# ### Category Concentration - Downloads vs. Competition
#
# **Challenge**:
# * First, create a DataFrame that has the number of apps in one column and the number of installs in another:
#
# <img src=https://imgur.com/uQRSlXi.png width="350">
#
# * Then use the [plotly express examples from the documentation](https://plotly.com/python/line-and-scatter/) alongside the [.scatter() API reference](https://plotly.com/python-api-reference/generated/plotly.express.scatter.html)to create scatter plot that looks like this.
#
# <img src=https://imgur.com/cHsqh6a.png>
#
# *Hint*: Use the size, hover_name and color parameters in .scatter(). To scale the yaxis, call .update_layout() and specify that the yaxis should be on a log-scale like so: yaxis=dict(type='log')

# %% [markdown]
# # Extracting Nested Data from a Column
#
# **Challenge**: How many different types of genres are there? Can an app belong to more than one genre? Check what happens when you use .value_counts() on a column with nested values? See if you can work around this problem by using the .split() function and the DataFrame's [.stack() method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.stack.html).

# %%
bar = px.bar(x=num_genres.index[:15], y=num_genres.values[:15], color=num_genres.values[:15], color_continuous_scale='agsunset', hover_name=num_genres.index[:15], title="Top Genres")
bar.update_layout(xaxis_title='Genre', yaxis_title='Number of Apps', coloraxis_showscale=False)
bar.update_xaxes(tickangle=15)
bar.show()

# %% [markdown]
# # Colour Scales in Plotly Charts - Competition in Genres

# %% [markdown]
# **Challenge**: Can you create this chart with the Series containing the genre data?
#
# <img src=https://imgur.com/DbcoQli.png width=400>
#
# Try experimenting with the built in colour scales in Plotly. You can find a full list [here](https://plotly.com/python/builtin-colorscales/).
#
# * Find a way to set the colour scale using the color_continuous_scale parameter.
# * Find a way to make the color axis disappear by using coloraxis_showscale.

# %% [markdown]
# # Grouped Bar Charts: Free vs. Paid Apps per Category

# %% [markdown]
# **Challenge**: Use the plotly express bar [chart examples](https://plotly.com/python/bar-charts/#bar-chart-with-sorted-or-ordered-categories) and the [.bar() API reference](https://plotly.com/python-api-reference/generated/plotly.express.bar.html#plotly.express.bar) to create this bar chart:
#
# <img src=https://imgur.com/LE0XCxA.png>
#
# You'll want to use the `df_free_vs_paid` DataFrame that you created above that has the total number of free and paid apps per category.
#
# See if you can figure out how to get the look above by changing the `categoryorder` to 'total descending' as outlined in the documentation here [here](https://plotly.com/python/categorical-axes/#automatically-sorting-categories-by-name-or-total-value).

# %%
df_free_vs_paid = df_apps_clean.groupby(["Category", "Type"], as_index=False).agg({"App": pd.Series.count})
df_free_vs_paid
# Out:
#              Category  Type  App
# 0      ART_AND_DESIGN  Free   59
# 1      ART_AND_DESIGN  Paid    3
# 2   AUTO_AND_VEHICLES  Free   72
# 3   AUTO_AND_VEHICLES  Paid    1
# 4              BEAUTY  Free   42
# ..                ...   ...  ...
# 56   TRAVEL_AND_LOCAL  Paid    8
# 57      VIDEO_PLAYERS  Free  156
# 58      VIDEO_PLAYERS  Paid    4
# 59            WEATHER  Free   68
# 60            WEATHER  Paid    7
#
# [61 rows x 3 columns]

# %%
bar = px.bar(df_free_vs_paid, x=df_free_vs_paid.Category, y=df_free_vs_paid.App, title="Free vs Paid App by Category", color="Type", barmode="group")
bar.update_layout(xaxis_title="Category", yaxis_title="Number of Apps", xaxis={"categoryorder": "total descending"}, yaxis=dict(type='log'))
# bar.update_xaxes(tickangle=15)
# bar.update_xaxes(categoryorder='total descending')
bar.show()

# %% [markdown]
# # Plotly Box Plots: Lost Downloads for Paid Apps
#
# **Challenge**: Create a box plot that shows the number of Installs for free versus paid apps. How does the median number of installations compare? Is the difference large or small?
#
# Use the [Box Plots Guide](https://plotly.com/python/box-plots/) and the [.box API reference](https://plotly.com/python-api-reference/generated/plotly.express.box.html) to create the following chart.
#
# <img src=https://imgur.com/uVsECT3.png>

# %%
box = px.box(df_apps_clean, x="Type", y="Installs", notched=True, points="all", color="Type", boxmode='group', title='How many downloads are Paid Apps Giving Up?')
box.update_layout(xaxis_title="Type", )

# %% [markdown]
# # Plotly Box Plots: Revenue by App Category
#
# **Challenge**: See if you can generate the chart below:
#
# <img src=https://imgur.com/v4CiNqX.png>
#
# Looking at the hover text, how much does the median app earn in the Tools category? If developing an Android app costs $30,000 or thereabouts, does the average photography app recoup its development costs?
#
# Hint: I've used 'min ascending' to sort the categories.

# %%
df_paid_apps = df_apps_clean[df_apps_clean['Type'] == 'Paid']
box = px.box(df_paid_apps, x='Category', y="Revenue Estimate", title="How much can Paid Apps Earn?")
box.update_layout(xaxis_title='Category', yaxis_title="Paid Apps Ballpark Revenue", xaxis=dict(categoryorder="min ascending"), yaxis=dict(type="log"))

box.show()

# %% [markdown]
# # How Much Can You Charge? Examine Paid App Pricing Strategies by Category
#
# **Challenge**: What is the median price price for a paid app? Then compare pricing by category by creating another box plot. But this time examine the prices (instead of the revenue estimates) of the paid apps. I recommend using `{categoryorder':'max descending'}` to sort the categories.

# %%
box = px.box(df_paid_apps, x='Category', y="Revenue Estimate", title="How much can Paid Apps Earn?")
box.update_layout(xaxis_title='Category', yaxis_title="Paid Apps Ballpark Revenue", xaxis=dict(categoryorder="max descending"), yaxis=dict(type="log"))

box.show()
